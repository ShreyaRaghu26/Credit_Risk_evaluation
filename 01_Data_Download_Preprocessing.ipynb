# %%
import pandas as pd  # is used for data manipulation.
import numpy as np  # helps with numerical operation

# %%
chunk_size = 1000000  

# Initialize a list to store chunks (if needed)
sampled_data_list = []

# Read the large file in chunks
for chunk in pd.read_csv("Data/train_data.csv", chunksize=chunk_size):
    print(f"Processing a new chunk of {len(chunk)} rows")
    
    # Example processing: Display first few rows of the chunk
    print(chunk.head())
    
    # If required, store processed chunks in a list
    sampled_data_list.append(chunk)  # Append for further processing

# Merge chunks if necessary
train_data = pd.concat(sampled_data_list, ignore_index=True)

# Display shape of the full dataset after reading in chunks
print("Final dataset shape:", train_data.shape)
# Out:
# Processing a new chunk of 1000000 rows
#                                          customer_ID         S_2       P_2  \
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-03-09  0.938469
# 1  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-04-07  0.936665
# 2  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-05-28  0.954180
# 3  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-06-13  0.960384
# 4  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-07-16  0.947248
#
#        D_39       B_1       B_2       R_1       S_3      D_41       B_3  ...  \
# 0  0.001733  0.008724  1.006838  0.009228  0.124035  0.008771  0.004709  ...
# 1  0.005775  0.004923  1.000653  0.006151  0.126750  0.000798  0.002714  ...
# 2  0.091505  0.021655  1.009672  0.006815  0.123977  0.007598  0.009423  ...
# 3  0.002455  0.013683  1.002700  0.001373  0.117169  0.000685  0.005531  ...
# 4  0.002483  0.015193  1.000727  0.007605  0.117325  0.004653  0.009312  ...
#
#    D_136  D_137  D_138     D_139     D_140     D_141  D_142     D_143  \
# 0    NaN    NaN    NaN  0.002427  0.003706  0.003818    NaN  0.000569
# 1    NaN    NaN    NaN  0.003954  0.003167  0.005032    NaN  0.009576
# 2    NaN    NaN    NaN  0.003269  0.007329  0.000427    NaN  0.003429
# 3    NaN    NaN    NaN  0.006117  0.004516  0.003200    NaN  0.008419
# 4    NaN    NaN    NaN  0.003671  0.004946  0.008889    NaN  0.001670
#
#       D_144     D_145
# 0  0.000610  0.002674
# 1  0.005492  0.009217
# 2  0.006986  0.002603
# 3  0.006527  0.009600
# 4  0.008126  0.009827
#
# [5 rows x 190 columns]
# Processing a new chunk of 1000000 rows
#                                                customer_ID         S_2  \
# 1000000  2e3fc76a68eeae6697b0a6b10f9288b7acaa678bbf99cd...  2017-04-28
# 1000001  2e3fc76a68eeae6697b0a6b10f9288b7acaa678bbf99cd...  2017-05-25
# 1000002  2e3fc76a68eeae6697b0a6b10f9288b7acaa678bbf99cd...  2017-06-23
# 1000003  2e3fc76a68eeae6697b0a6b10f9288b7acaa678bbf99cd...  2017-07-29
# 1000004  2e3fc76a68eeae6697b0a6b10f9288b7acaa678bbf99cd...  2017-08-20
#
#               P_2      D_39       B_1       B_2       R_1       S_3      D_41  \
# 1000000  0.705263  0.001339  0.206220  0.173391  0.006730  0.485036  0.005187
# 1000001  0.689844  0.009328  0.233954  0.060723  0.005931  0.490809  0.002118
# 1000002  0.640162  0.001031  0.274095  0.075871  0.009154  0.556885  0.005518
# 1000003  0.699427  0.039313  0.248987  0.041078  0.008561  0.507344  0.002570
# 1000004  0.703959  0.680710  0.385725  0.041097  0.002338  0.486602  0.000578
#
#               B_3  ...  D_136  D_137  D_138     D_139     D_140     D_141  \
# 1000000  0.198334  ...    NaN    NaN    NaN  0.000912  0.002812  0.005656
# 1000001  0.227002  ...    NaN    NaN    NaN  0.000464  0.001150  0.004924
# 1000002  0.335335  ...    NaN    NaN    NaN  0.004710  0.004418  0.000306
# 1000003  0.304296  ...    NaN    NaN    NaN  0.007758  0.003712  0.004754
# 1000004  0.304601  ...    NaN    NaN    NaN  0.006290  0.004671  0.001428
#
#          D_142     D_143     D_144     D_145
# 1000000    NaN  0.002974  0.003681  0.003376
# 1000001    NaN  0.000841  0.005128  0.008290
# 1000002    NaN  0.003542  0.004797  0.002379
# 1000003    NaN  0.002945  0.009550  0.003115
# 1000004    NaN  0.006029  0.009516  0.001032
#
# [5 rows x 190 columns]
# Processing a new chunk of 1000000 rows
#                                                customer_ID         S_2  \
# 2000000  5c4e9eaf09e51825e1b20a9c1a8768aa940d673544befc...  2018-01-27
# 2000001  5c4e9eaf09e51825e1b20a9c1a8768aa940d673544befc...  2018-02-24
# 2000002  5c4e9eaf09e51825e1b20a9c1a8768aa940d673544befc...  2018-03-27
# 2000003  5c4eaf9c854b6e69efce2563f5e97f737761649126011b...  2017-03-20
# 2000004  5c4eaf9c854b6e69efce2563f5e97f737761649126011b...  2017-04-25
#
#               P_2      D_39       B_1       B_2       R_1       S_3      D_41  \
# 2000000  0.397522  0.033193  0.034563  0.331052  0.005499       NaN  0.173371
# 2000001  0.399595  0.030300  0.028655  0.137440  0.009306       NaN  0.009612
# 2000002  0.405462  0.035090  0.024915  0.213955  0.006929       NaN  0.002198
# 2000003  0.567204  0.000654  1.283718  0.025981  0.009796  0.512927  0.008988
# 2000004  0.571073  0.001526  0.613275  0.029057  0.002039  0.307650  0.009494
#
#               B_3  ...  D_136  D_137  D_138     D_139     D_140     D_141  \
# 2000000  0.050111  ...    NaN    NaN    NaN  0.006413  0.005122  0.000703
# 2000001  0.144816  ...    NaN    NaN    NaN  0.007945  0.008778  0.003382
# 2000002  0.125682  ...    NaN    NaN    NaN  0.006840  0.007911  0.004598
# 2000003  1.167984  ...    NaN    NaN    NaN  0.002771  0.009234  0.001978
# 2000004  1.109925  ...    NaN    NaN    NaN  0.008325  0.001432  0.009164
#
#          D_142     D_143     D_144     D_145
# 2000000    NaN  0.008260  0.004152  0.008634
# 2000001    NaN  0.009980  0.000445  0.003260
# 2000002    NaN  0.004335  0.004544  0.008389
# 2000003    NaN  0.007548  0.009471  0.002190
# 2000004    NaN  0.004932  0.007641  0.006079
#
# [5 rows x 190 columns]
# Processing a new chunk of 1000000 rows
#                                                customer_ID         S_2  \
# 3000000  8a8a1c630b85c04a24c283748bc828d3f6240f440dc373...  2018-01-07
# 3000001  8a8a1c630b85c04a24c283748bc828d3f6240f440dc373...  2018-02-13
# 3000002  8a8a1c630b85c04a24c283748bc828d3f6240f440dc373...  2018-03-15
# 3000003  8a8a214875a82c8b06d5e29834a1d84c0e2c78019ed40a...  2017-03-17
# 3000004  8a8a214875a82c8b06d5e29834a1d84c0e2c78019ed40a...  2017-04-15
#
#               P_2      D_39       B_1       B_2       R_1       S_3      D_41  \
# 3000000  0.730172  0.009918  0.046525  1.002477  0.008097  0.170917  0.002211
# 3000001  0.714817  0.120984  0.034561  1.000025  0.000439  0.161163  0.005600
# 3000002  0.715442  0.059209  0.031431  1.004780  0.009497  0.153947  0.005994
# 3000003  0.826412  0.009867  0.001093  0.814311  0.007100       NaN  0.001099
# 3000004  0.814522  0.000585  0.003234  0.818343  0.004707       NaN  0.006213
#
#               B_3  ...  D_136  D_137  D_138     D_139     D_140     D_141  \
# 3000000  0.003297  ...    NaN    NaN    NaN  0.001457  0.007387  0.004942
# 3000001  0.005652  ...    NaN    NaN    NaN  0.007007  0.008120  0.003477
# 3000002  0.003653  ...    NaN    NaN    NaN  0.005869  0.002317  0.003179
# 3000003  0.002573  ...    NaN    NaN    NaN  0.006898  0.009006  0.004227
# 3000004  0.006789  ...    NaN    NaN    NaN  0.000874  0.002588  0.006915
#
#          D_142     D_143     D_144     D_145
# 3000000    NaN  0.009105  0.007905  0.009962
# 3000001    NaN  0.008425  0.001174  0.009081
# 3000002    NaN  0.009678  0.008229  0.004704
# 3000003    NaN  0.003837  0.004166  0.009788
# 3000004    NaN  0.003616  0.007000  0.004415
#
# [5 rows x 190 columns]
# Processing a new chunk of 1000000 rows
#                                                customer_ID         S_2  \
# 4000000  b8d4ad6125c7e43a34a68c2ae70ede7845b2a18b664293...  2018-02-13
# 4000001  b8d4ad6125c7e43a34a68c2ae70ede7845b2a18b664293...  2018-03-16
# 4000002  b8d4d685f485ff63b41172f89bba33954a7270334d9320...  2017-03-17
# 4000003  b8d4d685f485ff63b41172f89bba33954a7270334d9320...  2017-04-01
# 4000004  b8d4d685f485ff63b41172f89bba33954a7270334d9320...  2017-05-19
#
#               P_2      D_39       B_1       B_2       R_1       S_3      D_41  \
# 4000000  0.310297  0.038948  0.044681  0.230299  0.504357  0.163152  0.004406
# 4000001  0.309353  0.038408  0.040393  0.230439  0.004521  0.167098  0.001030
# 4000002  0.797072  0.000116  0.071084  1.005144  0.005900  0.152758  0.001779
# 4000003  0.693130  0.182545  0.223319  0.113085  0.009665  0.141863  0.005779
# 4000004  0.782199  0.715290  0.276582  0.061701  0.000179  0.148142  0.005670
#
#               B_3  ...  D_136  D_137  D_138     D_139     D_140     D_141  \
# 4000000  0.188099  ...    NaN    NaN    NaN  0.006040  0.003965  0.006755
# 4000001  0.182374  ...    NaN    NaN    NaN  0.004014  0.004528  0.005382
# 4000002  0.031694  ...    NaN    NaN    NaN  1.007697  0.000397  0.954824
# 4000003  0.074163  ...    NaN    NaN    NaN  1.002487  0.008386  0.953236
# 4000004  0.120692  ...    NaN    NaN    NaN  1.007697  0.007769  0.951603
#
#             D_142     D_143         D_144     D_145
# 4000000       NaN  0.003856  5.245467e-03  0.005659
# 4000001       NaN  0.004476  8.310934e-03  0.004719
# 4000002  0.592558  1.004698  7.942353e-07  2.368776
# 4000003  0.593430  1.003461  4.128935e-03  2.370532
# 4000004  0.606573  1.007902  7.487031e-03  2.367466
#
# [5 rows x 190 columns]
# Processing a new chunk of 531451 rows
#                                                customer_ID         S_2  \
# 5000000  e744f178b2179915a6012b54d080bbb0cdf558338a1e90...  2017-08-16
# 5000001  e744f178b2179915a6012b54d080bbb0cdf558338a1e90...  2017-09-15
# 5000002  e744f178b2179915a6012b54d080bbb0cdf558338a1e90...  2017-10-30
# 5000003  e744f178b2179915a6012b54d080bbb0cdf558338a1e90...  2017-11-15
# 5000004  e744f178b2179915a6012b54d080bbb0cdf558338a1e90...  2017-12-16
#
#               P_2      D_39       B_1       B_2       R_1       S_3      D_41  \
# 5000000  0.249347  0.036238  0.201302  0.001481  0.000634       NaN  0.792455
# 5000001  0.263052  0.912229  0.211717  0.009346  0.002608       NaN  0.809324
# 5000002  0.263631  0.449533  0.198803  0.088846  0.008032  0.170286  0.642533
# 5000003  0.260934  0.038280  0.219507  0.050620  0.003326  0.218049  0.414680
# 5000004  0.286260  0.033071  0.209893  0.046193  0.007625  0.213742  0.366021
#
#               B_3  ...  D_136  D_137  D_138     D_139     D_140     D_141  \
# 5000000  0.324472  ...    NaN    NaN    NaN  0.001661  0.002618  0.000116
# 5000001  0.437954  ...    NaN    NaN    NaN  0.007842  0.002418  0.002769
# 5000002  0.477244  ...    NaN    NaN    NaN  0.001102  0.004106  0.005483
# 5000003  0.378822  ...    NaN    NaN    NaN  0.007585  0.006066  0.001337
# 5000004  0.408357  ...    NaN    NaN    NaN  0.004587  0.000417  0.007719
#
#          D_142     D_143     D_144     D_145
# 5000000    NaN  0.002006  0.001340  0.008588
# 5000001    NaN  0.006550  0.002470  0.002282
# 5000002    NaN  0.004132  0.006230  0.004693
# 5000003    NaN  0.007095  0.002422  0.006719
# 5000004    NaN  0.001003  0.004600  0.004002
#
# [5 rows x 190 columns]
# Final dataset shape: (5531451, 190)

# %%
train_labels = pd.read_csv('Data/train_labels.csv')

# %%
train_lables_Sample = train_labels.sample(frac=0.2, random_state=42)

# %%
train_filt_label_data = pd.merge(train_lables_Sample,train_data,on='customer_ID',how='inner')
train_filt_label_data
# Out:
#                                                customer_ID  target  \
# 0        12c761e40348fa242de0356426fa9547f0feea34d1f57b...       0
# 1        12c761e40348fa242de0356426fa9547f0feea34d1f57b...       0
# 2        12c761e40348fa242de0356426fa9547f0feea34d1f57b...       0
# 3        12c761e40348fa242de0356426fa9547f0feea34d1f57b...       0
# 4        12c761e40348fa242de0356426fa9547f0feea34d1f57b...       0
# ...                                                    ...     ...
# 1107077  f0defebbf6e79c14234a06c5b3522ee5914cb0f23fdd13...       0
# 1107078  f0defebbf6e79c14234a06c5b3522ee5914cb0f23fdd13...       0
# 1107079  f0defebbf6e79c14234a06c5b3522ee5914cb0f23fdd13...       0
# 1107080  f0defebbf6e79c14234a06c5b3522ee5914cb0f23fdd13...       0
# 1107081  f0defebbf6e79c14234a06c5b3522ee5914cb0f23fdd13...       0
#
#                 S_2       P_2      D_39       B_1       B_2       R_1  \
# 0        2017-03-21  0.628534  0.004250  0.017667  0.815468  0.005736
# 1        2017-04-21  0.669914  0.418321  0.354284  1.000587  0.009774
# 2        2017-05-08  0.661933  0.003989  0.244867  1.008683  0.005743
# 3        2017-06-14  0.644270  0.009351  0.017799  0.668398  0.003148
# 4        2017-07-26  0.688055  0.002832  0.009458  0.779692  0.000870
# ...             ...       ...       ...       ...       ...       ...
# 1107077  2017-11-29  0.957207  0.003413  0.005511  0.811611  0.007821
# 1107078  2017-12-30  0.826494  0.007873  0.009774  0.819318  0.007074
# 1107079  2018-01-30  0.828001  0.002666  0.001569  0.815946  0.001636
# 1107080  2018-02-27  0.825479  0.001338  0.006197  0.812589  0.000352
# 1107081  2018-03-30  0.839816  0.006281  0.002410  0.818417  0.006255
#
#               S_3      D_41  ...  D_136  D_137  D_138     D_139     D_140  \
# 0        0.265531  0.005933  ...    NaN    NaN    NaN       NaN       NaN
# 1        0.176196  0.007370  ...    NaN    NaN    NaN  0.003869  0.008332
# 2        0.169471  0.005953  ...    NaN    NaN    NaN  0.004872  0.008471
# 3        0.174020  0.006656  ...    NaN    NaN    NaN  0.009246  0.009905
# 4        0.174547  0.009100  ...    NaN    NaN    NaN  0.004311  0.006488
# ...           ...       ...  ...    ...    ...    ...       ...       ...
# 1107077       NaN  0.002437  ...    NaN    NaN    NaN  0.003099  0.000731
# 1107078       NaN  0.006983  ...    NaN    NaN    NaN  0.007693  0.001338
# 1107079       NaN  0.005888  ...    NaN    NaN    NaN       NaN  0.006918
# 1107080       NaN  0.003774  ...    NaN    NaN    NaN  0.009021  0.006564
# 1107081       NaN  0.000225  ...    NaN    NaN    NaN  0.007648  0.002703
#
#             D_141  D_142     D_143     D_144     D_145
# 0             NaN    NaN       NaN       NaN       NaN
# 1        0.005805    NaN  0.006603  0.007874  0.002185
# 2        0.006763    NaN  0.009782  0.007285  0.000121
# 3        0.008673    NaN  0.003927  0.001159  0.000433
# 4        0.004953    NaN  0.009283  0.003769  0.006124
# ...           ...    ...       ...       ...       ...
# 1107077  0.006184    NaN  0.006376  0.003519  0.007407
# 1107078  0.001450    NaN  0.003571  0.001993  0.005287
# 1107079       NaN    NaN       NaN  0.001155       NaN
# 1107080  0.000960    NaN  0.001825  0.006149  0.009502
# 1107081  0.001718    NaN  0.005252  0.004685  0.004627
#
# [1107082 rows x 191 columns]

# %%
train_filt_label_data.to_csv("train_filt_label_data.csv")

# %%
from copy import deepcopy

temp_df = deepcopy(train_filt_label_data)

temp_df['temp_yearmonth']=train_filt_label_data.S_2.str.slice(0,7)

 
def_obs = temp_df[temp_df.target==1].groupby(['temp_yearmonth'],as_index=False)[['customer_ID']].count()

def_obs = def_obs.rename(columns={'customer_ID':'default_observation'})
 
tot_obs = temp_df.groupby(['temp_yearmonth'],as_index=False)[['customer_ID']].count()

tot_obs = tot_obs.rename(columns={'customer_ID':'total_observations'})
 
combined_obs = def_obs.merge(tot_obs,on=['temp_yearmonth'])

combined_obs['default_rate_per_month']=round(combined_obs.default_observation/combined_obs.total_observations,4)

combined_obs
# Out:
#    temp_yearmonth  default_observation  total_observations  \
# 0         2017-03                18209               79285
# 1         2017-04                18824               80471
# 2         2017-05                18928               80174
# 3         2017-06                19686               82129
# 4         2017-07                20221               83211
# 5         2017-08                20722               84262
# 6         2017-09                21125               85149
# 7         2017-10                21538               86072
# 8         2017-11                21898               86876
# 9         2017-12                22302               87783
# 10        2018-01                22740               89288
# 11        2018-02                23158               90599
# 12        2018-03                23543               91783
#
#     default_rate_per_month
# 0                   0.2297
# 1                   0.2339
# 2                   0.2361
# 3                   0.2397
# 4                   0.2430
# 5                   0.2459
# 6                   0.2481
# 7                   0.2502
# 8                   0.2521
# 9                   0.2541
# 10                  0.2547
# 11                  0.2556
# 12                  0.2565

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# Step 1: Load the first chunk of the training data to get column names
# You only need the first row to inspect structure
train_sample = pd.read_csv("Data/train_data.csv", nrows=1)  # Update path if needed
columns = train_sample.columns.tolist()

# Step 2: Extract prefixes (like D, S, P, B, R)
prefixes = [col.split('_')[0] for col in columns if '_' in col and col != 'S_2']

# Step 3: Count how many columns fall under each prefix
prefix_counts = dict(Counter(prefixes))
prefix_df = pd.DataFrame(list(prefix_counts.items()), columns=["Category Prefix", "Count"]).sort_values(by="Category Prefix")

# Step 4: Plot the results
plt.figure(figsize=(8, 5))
bars = plt.bar(prefix_df["Category Prefix"], prefix_df["Count"], color='Orange')

# Add count labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height + 1, str(int(height)), ha='center', fontsize=10)

plt.title("Count of Columns by Category Prefix")
plt.xlabel("Category Prefix")
plt.ylabel("Count")
plt.tight_layout()

# Step 5: Save chart (optional)
plt.savefig("Category_Prefix_Counts_From_Real_Data.png")
plt.show()

# %%
# Step 1: Calculate the total count of null values and their percentages
Count_Null = train_filt_label_data.isnull().sum()
Count_Null_percentage = ((train_filt_label_data.isnull().sum() / len(train_filt_label_data)) * 100).round(2)
null_df = pd.DataFrame({
    'Null Value Count': Count_Null,
    'Null Value Percent(%)': Count_Null_percentage
})
null_df_sorted = null_df.sort_values(by='Null Value Count', ascending=False)
null_df_sorted
# Out:
#        Null Value Count  Null Value Percent(%)
# D_87            1106268                  99.93
# D_88            1105909                  99.89
# D_108           1101423                  99.49
# D_110           1100434                  99.40
# D_111           1100434                  99.40
# ...                 ...                    ...
# D_96                  0                   0.00
# B_36                  0                   0.00
# R_24                  0                   0.00
# D_127                 0                   0.00
# R_28                  0                   0.00
#
# [191 rows x 2 columns]

# %%
# Count features with more than 20% missing values
features_to_drop = null_df_sorted[null_df_sorted['Null Value Percent(%)'] > 20].index.tolist()
count_dropped_features = len(features_to_drop)

# Drop the features with more than 20% missing values
train_date_filtered = train_filt_label_data.drop(columns=features_to_drop)

# Output the results
print(f"Count of features with more than 20% missing values: {count_dropped_features}")
print("Dropped features:", features_to_drop)
# Out:
# Count of features with more than 20% missing values: 34
# Dropped features: ['D_87', 'D_88', 'D_108', 'D_110', 'D_111', 'B_39', 'D_73', 'B_42', 'D_138', 'D_135', 'D_134', 'D_137', 'D_136', 'R_9', 'B_29', 'D_106', 'D_132', 'D_49', 'R_26', 'D_66', 'D_76', 'D_42', 'D_142', 'D_53', 'D_82', 'D_50', 'B_17', 'D_105', 'D_56', 'S_9', 'D_77', 'D_43', 'S_27', 'D_46']

# %%
cat_feature = ['B_30', 'B_38', 'D_114', 'D_116', 'D_117', 'D_120', 'D_126', 'D_63', 'D_64', 'D_68']

train_encoded = pd.get_dummies(train_filt_label_data,columns=cat_feature,drop_first=False)

# %%
cols_with_B30 = train_encoded.filter(like='B_30').columns.tolist()

print(cols_with_B30)
# Out:
# ['B_30_0.0', 'B_30_1.0', 'B_30_2.0']

# %%
train_filt_label_data.shape
# Out:
# (1107082, 191)

# %%
train_encoded.shape
# Out:
# (1107082, 224)

# %%
train_encoded.to_csv('01_Data_Download_Preprocessing_onehotencoding.csv')
